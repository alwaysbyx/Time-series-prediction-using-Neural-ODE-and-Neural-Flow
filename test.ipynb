# %%
import numpy as np
import torch

# %%
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sir --extrap --z0-encoder flow --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data pp --extrap --z0-encoder flow --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data population --extrap --z0-encoder flow --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine2 --extrap --z0-encoder flow --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine --extrap --z0-encoder flow --wandb 1
# Out:
# Couldn't import umap
# Sampling dataset of 1000 training examples
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/lib/plotting.py:167: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show(block=False)
# wandb: Currently logged in as: alwaysbb. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.13.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/wandb/run-20221104_233342-24o3bhim
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run twilight-meadow-37
# wandb: ⭐️ View project at https://wandb.ai/alwaysbb/latent
# wandb: 🚀 View run at https://wandb.ai/alwaysbb/latent/runs/24o3bhim
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/run_models.py
# ...

# %%
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine --extrap --z0-encoder ode --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sir --extrap --z0-encoder ode --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data pp --extrap --z0-encoder ode --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data population --extrap --z0-encoder ode --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine2 --extrap --z0-encoder ode --wandb 1
# Out:
# Couldn't import umap
# Sampling dataset of 1000 training examples
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/lib/plotting.py:135: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show(block=False)
# wandb: Currently logged in as: alwaysbb. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.13.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/wandb/run-20221108_171750-vhinmzpi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run still-frost-42
# wandb: ⭐️ View project at https://wandb.ai/alwaysbb/latent
# wandb: 🚀 View run at https://wandb.ai/alwaysbb/latent/runs/vhinmzpi
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/run_models.py
# ...

# %%
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine --extrap --z0-encoder flow --flow-model resnet --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sir --extrap --z0-encoder flow --flow-model resnet --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data pp --extrap --z0-encoder flow --flow-model resnet --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data population --extrap --z0-encoder flow --flow-model resnet --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine2 --extrap --z0-encoder flow --flow-model resnet --wandb 1
# Out:
# Couldn't import umap
# Sampling dataset of 1000 training examples
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/lib/plotting.py:135: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show(block=False)
# wandb: Currently logged in as: alwaysbb. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.13.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/wandb/run-20221108_200205-1cdoflu1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run splendid-sunset-47
# wandb: ⭐️ View project at https://wandb.ai/alwaysbb/latent
# wandb: 🚀 View run at https://wandb.ai/alwaysbb/latent/runs/1cdoflu1
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/run_models.py
# ...

# %%
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine --extrap --z0-encoder flow --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sir --extrap --z0-encoder flow --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data pp --extrap --z0-encoder flow  --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data population --extrap --z0-encoder flow --wandb 1
# !python run_models.py --latent-ode --noise-weight 0.01 --viz --data sine2 --extrap --z0-encoder flow --wandb 1
# Out:
# Couldn't import umap
# Sampling dataset of 1000 training examples
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/lib/plotting.py:135: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show(block=False)
# wandb: Currently logged in as: alwaysbb. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.13.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/wandb/run-20221108_225706-10yn3se2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run youthful-planet-52
# wandb: ⭐️ View project at https://wandb.ai/alwaysbb/latent
# wandb: 🚀 View run at https://wandb.ai/alwaysbb/latent/runs/10yn3se2
# /Users/bb/Desktop/UCSD/Quarters/22Fall/CSE291/latent_ode/run_models.py
# ...

# %%
from lib.create_latent_ode_model2 import create_LatentODE_model
import lib.utils as utils

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
ckpt_path = 'experiments/experiment_sine_extrap.ckpt'
class Args():
    def __init__(self, model, flow_model='coupling',data='sine2'):

# %%
model = create_LatentODE_model(args, input_dim, z0_prior, obsrv_std, device,  classif_per_tp = classif_per_tp,  n_labels = n_labels)
utils.get_ckpt_model(ckpt_path, model, device)
